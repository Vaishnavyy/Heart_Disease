# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv("E:/heart_diseaase/Heart Disease data.csv")

# %% [markdown]
# * age
# * sex
# * chest pain type (4 values) -> cp
#   *   Value 0: typical angina
#   *   Value 1: atypical angina
#   *   value 2: non-anginal pain
#   *   value 3: asymptomatic
# * trestbps: resting blood pressure (in mm Hg)
# * chol: serum cholestoral in mg/dl
# * (fbs) -> fasting blood sugar -> 120 mg/dl
#   *   0: false
#   *   1: true
# * restecg -> resting electrocardiographic results (values 0,1,2)
#   *   Value 0: normal
#   *   Value 1: having ST-T
#   *   value 2: showing probable or definite left ventricular
# * thalach -> maximum heart rate achieved
# * exang -> exercise induced angina (1 = yes, 0 = no)
# * oldpeak = ST depression induced by exercise relative to rest
# * slope -> the slope of the peak exercise ST segment
#   *   Value 1: upsloping
#   *   Value 2: flat
#   *   value 3: downsloping
# * ca -> number of major vessels (0-3) colored by flourosopy
# * thal -> 3 = normal; 6 = fixed defect; 7 = reversable defect
# * target -> 0 = less chance of heart attack, 1 = more chance of heart attack

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data.shape
# Out:
# (1025, 14)

# %%
data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
duplicate_rows = data[data.duplicated()]

# %%
# Display the duplicate rows
print("Duplicate Rows:")
print(duplicate_rows)
# Out:
# Duplicate Rows:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 15     34    0   1       118   210    0        1      192      0      0.7
# 31     50    0   1       120   244    0        1      162      0      1.1
# 43     46    1   0       120   249    0        0      144      0      0.8
# 55     55    1   0       140   217    0        1      111      1      5.6
# 61     66    0   2       146   278    0        0      152      0      0.0
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 15        2   0     2       1
# 31        2   0     2       1
# 43        2   0     3       0
# 55        0   0     3       0
# 61        1   1     2       1
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [723 rows x 14 columns]

# %%
# Remove duplicate rows
data_cleaned = data.drop_duplicates()

# %%
# Verify removal of duplicates
print("Number of rows after removing duplicates:", data_cleaned.shape[0])
print("Number of cols after removing duplicates:", data_cleaned.shape[1])
# Out:
# Number of rows after removing duplicates: 302
# Number of cols after removing duplicates: 14

# %%
data_cleaned.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# std      0.526027   22.903527    0.470196    1.161452    0.616274    1.006748
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.250000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  152.500000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  302.000000  302.000000
# mean     2.314570    0.543046
# std      0.613026    0.498970
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
plt.figure(figsize = (17, 6))
sns.heatmap(data.corr(), annot = True)
# Out:
# <Axes: >

# %%
data_cleaned['target'].value_counts()
# Out:
# target
# 1    164
# 0    138
# Name: count, dtype: int64

# %%
#Converting Numerical Data into Categorical Data

def heart_disease(row):
    if row == 0:
        return 'less chance'
    elif row == 1:
        return 'more chance'

# %%
#Applying converted data into our dataset with new column - Heart_Disease
data_cleaned['Heart_Disease']= data_cleaned['target'].apply(heart_disease)
data_cleaned.head()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_3324\2082570507.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['Heart_Disease']= data_cleaned['target'].apply(heart_disease)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target Heart_Disease
# 0   2     3       0   less chance
# 1   0     3       0   less chance
# 2   0     3       0   less chance
# 3   1     3       0   less chance
# 4   3     2       0   less chance

# %%
data_cleaned['Heart_Disease'].value_counts()
# Out:
# Heart_Disease
# more chance    164
# less chance    138
# Name: count, dtype: int64

# %%
#Statistical Analysis
Min_Age = data_cleaned['age'].min()
Max_Age = data_cleaned['age'].max()
Mean_Age = data_cleaned['age'].mean()

print("Minimum Age =",Min_Age)
print("Maximum Age =",Max_Age)
print("Mean Age =",Mean_Age)
# Out:
# Minimum Age = 29
# Maximum Age = 77
# Mean Age = 54.420529801324506

# %%
#Categorical Analysis

def age(row):
    if (row >= 29 and row < 40):
        return 'Young'
    elif (row >= 40 and row < 55):
        return 'Adult'
    elif (row >= 55):
        return 'Elder'

# %%
data_cleaned['Age1'] = data_cleaned['age'].apply(age)
data_cleaned.head()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_3324\2015183545.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['Age1'] = data_cleaned['age'].apply(age)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target Heart_Disease   Age1
# 0   2     3       0   less chance  Adult
# 1   0     3       0   less chance  Adult
# 2   0     3       0   less chance  Elder
# 3   1     3       0   less chance  Elder
# 4   3     2       0   less chance  Elder

# %%
data_cleaned['Age1'].value_counts()
# Out:
# Age1
# Elder    159
# Adult    128
# Young     15
# Name: count, dtype: int64

# %%
#Converting Numerical Data into Categorical Data

def gender(row):
    if row == 1:
        return 'Male'
    elif row == 0:
        return 'Female'

# %%
#Applying converted data into our dataset with new column - sex1

data_cleaned['sex1'] = data_cleaned['sex'].apply(gender)
data_cleaned.head()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_3324\326721122.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['sex1'] = data_cleaned['sex'].apply(gender)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target Heart_Disease   Age1    sex1
# 0   2     3       0   less chance  Adult    Male
# 1   0     3       0   less chance  Adult    Male
# 2   0     3       0   less chance  Elder    Male
# 3   1     3       0   less chance  Elder    Male
# 4   3     2       0   less chance  Elder  Female

# %%
data_cleaned['cp'].value_counts()
# Out:
# cp
# 0    143
# 2     86
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
def chest_pain(row):
    if row == 0:
      return 'typical angina'
    elif row == 1:
      return 'atypical angina'
    elif row == 2:
      return 'non-anginal pain'
    elif row == 3:
      return 'asymptomatic'

# %%
data_cleaned['Chest_Pain'] = data_cleaned['cp'].apply(chest_pain)
data_cleaned.head()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_3324\3916768591.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['Chest_Pain'] = data_cleaned['cp'].apply(chest_pain)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target Heart_Disease   Age1    sex1      Chest_Pain
# 0   2     3       0   less chance  Adult    Male  typical angina
# 1   0     3       0   less chance  Adult    Male  typical angina
# 2   0     3       0   less chance  Elder    Male  typical angina
# 3   1     3       0   less chance  Elder    Male  typical angina
# 4   3     2       0   less chance  Elder  Female  typical angina

# %%
data_cleaned['Chest_Pain'].value_counts()
# Out:
# Chest_Pain
# typical angina      143
# non-anginal pain     86
# atypical angina      50
# asymptomatic         23
# Name: count, dtype: int64

# %%
data_cleaned['fbs'].value_counts()
# Out:
# fbs
# 0    257
# 1     45
# Name: count, dtype: int64

# %%
def fb(row):
    if row == 0:
      return 'false'
    elif row == 1:
      return 'true'

# %%
data_cleaned['Fasting_Blood_Sugar'] = data_cleaned['fbs'].apply(fb)
data_cleaned.head()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_3324\41948683.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['Fasting_Blood_Sugar'] = data_cleaned['fbs'].apply(fb)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target Heart_Disease   Age1    sex1      Chest_Pain  \
# 0   2     3       0   less chance  Adult    Male  typical angina
# 1   0     3       0   less chance  Adult    Male  typical angina
# 2   0     3       0   less chance  Elder    Male  typical angina
# 3   1     3       0   less chance  Elder    Male  typical angina
# 4   3     2       0   less chance  Elder  Female  typical angina
#
#   Fasting_Blood_Sugar
# 0               false
# 1                true
# 2               false
# 3               false
# 4                true

# %%
data_cleaned['Fasting_Blood_Sugar'].value_counts()
# Out:
# Fasting_Blood_Sugar
# false    257
# true      45
# Name: count, dtype: int64

# %%
data_cleaned['exang'].value_counts()
# Out:
# exang
# 0    203
# 1     99
# Name: count, dtype: int64

# %%
def ang(row):
  if row == 0:
    return 'No'
  elif row == 1:
    return 'yes'

# %%
data_cleaned['Ex_angina'] = data_cleaned['exang'].apply(ang)
data_cleaned.head()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_3324\1806897255.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['Ex_angina'] = data_cleaned['exang'].apply(ang)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target Heart_Disease   Age1    sex1      Chest_Pain  \
# 0   2     3       0   less chance  Adult    Male  typical angina
# 1   0     3       0   less chance  Adult    Male  typical angina
# 2   0     3       0   less chance  Elder    Male  typical angina
# 3   1     3       0   less chance  Elder    Male  typical angina
# 4   3     2       0   less chance  Elder  Female  typical angina
#
#   Fasting_Blood_Sugar Ex_angina
# 0               false        No
# 1                true       yes
# 2               false       yes
# 3               false        No
# 4                true        No

# %%
data_cleaned['slope'].value_counts()
# Out:
# slope
# 2    141
# 1    140
# 0     21
# Name: count, dtype: int64

# %%
def slope(row):
  if row == 0:
    return 'Downsloping'
  elif row == 1:
    return 'Flat'
  elif row == 2:
    return 'Upsloping'

# %%
data_cleaned['Slope1'] = data_cleaned['slope'].apply(slope)
data_cleaned.head()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_3324\2451888951.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['Slope1'] = data_cleaned['slope'].apply(slope)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  ...  \
# 0   52    1   0       125   212    0        1      168      0      1.0  ...
# 1   53    1   0       140   203    1        0      155      1      3.1  ...
# 2   70    1   0       145   174    0        1      125      1      2.6  ...
# 3   61    1   0       148   203    0        1      161      0      0.0  ...
# 4   62    0   0       138   294    1        1      106      0      1.9  ...
#
#    ca  thal  target  Heart_Disease   Age1    sex1      Chest_Pain  \
# 0   2     3       0    less chance  Adult    Male  typical angina
# 1   0     3       0    less chance  Adult    Male  typical angina
# 2   0     3       0    less chance  Elder    Male  typical angina
# 3   1     3       0    less chance  Elder    Male  typical angina
# 4   3     2       0    less chance  Elder  Female  typical angina
#
#   Fasting_Blood_Sugar Ex_angina       Slope1
# 0               false        No    Upsloping
# 1                true       yes  Downsloping
# 2               false       yes  Downsloping
# 3               false        No    Upsloping
# 4                true        No         Flat
#
# [5 rows x 21 columns]

# %%
data_cleaned['thal'].unique()
# Out:
# array([3, 2, 1, 0], dtype=int64)

# %%
def thal(row):
  if row == 0:
    return 'Fixed Defect'
  elif row == 1:
    return 'Normal'
  elif row == 2:
    return 'Not Described'
  elif row == 3:
    return 'Reversible Effect'

# %%
data_cleaned['Thalenium'] = data_cleaned['thal'].apply(thal)
data_cleaned.head()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_3324\3402349687.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['Thalenium'] = data_cleaned['thal'].apply(thal)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  ...  \
# 0   52    1   0       125   212    0        1      168      0      1.0  ...
# 1   53    1   0       140   203    1        0      155      1      3.1  ...
# 2   70    1   0       145   174    0        1      125      1      2.6  ...
# 3   61    1   0       148   203    0        1      161      0      0.0  ...
# 4   62    0   0       138   294    1        1      106      0      1.9  ...
#
#    thal  target  Heart_Disease   Age1    sex1      Chest_Pain  \
# 0     3       0    less chance  Adult    Male  typical angina
# 1     3       0    less chance  Adult    Male  typical angina
# 2     3       0    less chance  Elder    Male  typical angina
# 3     3       0    less chance  Elder    Male  typical angina
# 4     2       0    less chance  Elder  Female  typical angina
#
#   Fasting_Blood_Sugar Ex_angina       Slope1          Thalenium
# 0               false        No    Upsloping  Reversible Effect
# 1                true       yes  Downsloping  Reversible Effect
# 2               false       yes  Downsloping  Reversible Effect
# 3               false        No    Upsloping  Reversible Effect
# 4                true        No         Flat      Not Described
#
# [5 rows x 22 columns]

# %%
data_cleaned['restecg'].value_counts()
# Out:
# restecg
# 1    151
# 0    147
# 2      4
# Name: count, dtype: int64

# %%
def ecg(row):
  if row == 0:
    return 'normal'
  elif row == 1:
    return 'having ST-T wave abnormality'
  elif row == 2:
    return 'showing probable or definite left ventricular hypertrophy'

# %%
data_cleaned['Resting ECG'] = data_cleaned['restecg'].apply(ecg)
data_cleaned.head()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_3324\2837131157.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['Resting ECG'] = data_cleaned['restecg'].apply(ecg)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  ...  \
# 0   52    1   0       125   212    0        1      168      0      1.0  ...
# 1   53    1   0       140   203    1        0      155      1      3.1  ...
# 2   70    1   0       145   174    0        1      125      1      2.6  ...
# 3   61    1   0       148   203    0        1      161      0      0.0  ...
# 4   62    0   0       138   294    1        1      106      0      1.9  ...
#
#    target  Heart_Disease   Age1    sex1      Chest_Pain Fasting_Blood_Sugar  \
# 0       0    less chance  Adult    Male  typical angina               false
# 1       0    less chance  Adult    Male  typical angina                true
# 2       0    less chance  Elder    Male  typical angina               false
# 3       0    less chance  Elder    Male  typical angina               false
# 4       0    less chance  Elder  Female  typical angina                true
#
#   Ex_angina       Slope1          Thalenium                   Resting ECG
# 0        No    Upsloping  Reversible Effect  having ST-T wave abnormality
# 1       yes  Downsloping  Reversible Effect                        normal
# 2       yes  Downsloping  Reversible Effect  having ST-T wave abnormality
# 3        No    Upsloping  Reversible Effect  having ST-T wave abnormality
# 4        No         Flat      Not Described  having ST-T wave abnormality
#
# [5 rows x 23 columns]

# %%
data_cleaned.drop(columns=['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'thal', 'target'], inplace=True)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_3324\646640509.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned.drop(columns=['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'thal', 'target'], inplace=True)

# %%
data_cleaned.head()
# Out:
#    age  trestbps  chol  thalach  oldpeak  ca Heart_Disease   Age1    sex1  \
# 0   52       125   212      168      1.0   2   less chance  Adult    Male
# 1   53       140   203      155      3.1   0   less chance  Adult    Male
# 2   70       145   174      125      2.6   0   less chance  Elder    Male
# 3   61       148   203      161      0.0   1   less chance  Elder    Male
# 4   62       138   294      106      1.9   3   less chance  Elder  Female
#
#        Chest_Pain Fasting_Blood_Sugar Ex_angina       Slope1  \
# 0  typical angina               false        No    Upsloping
# 1  typical angina                true       yes  Downsloping
# 2  typical angina               false       yes  Downsloping
# 3  typical angina               false        No    Upsloping
# 4  typical angina                true        No         Flat
#
#            Thalenium                   Resting ECG
# 0  Reversible Effect  having ST-T wave abnormality
# 1  Reversible Effect                        normal
# 2  Reversible Effect  having ST-T wave abnormality
# 3  Reversible Effect  having ST-T wave abnormality
# 4      Not Described  having ST-T wave abnormality

# %%
data_cleaned.shape
# Out:
# (302, 15)

# %%
data_cleaned.to_excel('cleaned_data.xlsx', index = False)
